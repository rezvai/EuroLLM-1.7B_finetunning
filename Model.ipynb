# %% [markdown]
# ## 1. Downloading the pre-trained model

# %%
from huggingface_hub import login
import os 

token = os.getenv("HUGGINGFACE_TOKEN")

login(token=token)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "utter-project/EuroLLM-1.7B-Instruct",
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained("utter-project/EuroLLM-1.7B-Instruct")
tokenizer.pad_token = tokenizer.eos_token
# Out:
# c:\Users\artem\anaconda3\envs\llm_training\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\artem\.cache\huggingface\hub\models--utter-project--EuroLLM-1.7B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %% [markdown]
# ## 2. Downloading and formating the dataset

# %%
from datasets import load_dataset

dataset = load_dataset("ai-forever/POLLUX", split="test[:20000]")

def format(example):
  text = f"<s>[INST] {example['instruction']}[/INST] {example['answer']}</s>"

  tokens = tokenizer(
    text,
    max_length=512,
    truncation=True,
    padding="max_length",
    return_tensors="pt"
  )

  labels = tokens['input_ids'].clone()

  inst_token_id = tokenizer.convert_tokens_to_ids("[/INST]")
  if inst_token_id in tokens["input_ids"][0]:
    end_idx = (tokens["input_ids"][0] == inst_token_id).nonzero(as_tuple=True)[0][-1].item()
    labels[0, :end_idx+1] = -100

  tokens['labels'] = labels

  return {k: v[0] for k, v in tokens.items()}

dataset = dataset.map(format, remove_columns=dataset.column_names)
# Out:
# Map: 100%|██████████| 20000/20000 [00:23<00:00, 846.91 examples/s]

# %% [markdown]
# ## 3. Preparating for the finetuning

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    target_modules=['q_proj', 'v_proj'],
    lora_dropout=0.05,
    bias='none',
    task_type=TaskType.CAUSAL_LM
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 11,010,048 || all params: 1,667,860,480 || trainable%: 0.6601

# %% [markdown]
# ## 4. Train the model

# %%
from transformers import TrainingArguments
import torch

torch.backends.cuda.enable_flash_sdp(False)
torch.backends.cuda.enable_mem_efficient_sdp(False)
torch.backends.cuda.enable_math_sdp(True)

training_args = TrainingArguments(
    output_dir="./EURO_LLM_LORA",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=8,
    logging_steps=10,
    save_steps=100,
    num_train_epochs=3,
    fp16=True,
    save_total_limit=2,
    report_to="none",
)

from transformers import Trainer, DataCollatorForLanguageModeling

trainer = Trainer(
    model=model,
    train_dataset=dataset,
    args=training_args,
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

trainer.train()

# %% [markdown]
# ___

# %% [markdown]
# ## 5. Test the model and print metrics

# %% [markdown]
# ###### Uploading model weights

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
from safetensors.torch import load_file
from peft import get_peft_model, LoraConfig

lora_checkpoint = r"EURO_LLM_LORA\checkpoint-3750\model.safetensors"
base_model = "utter-project/EuroLLM-1.7B-Instruct"
device = "cuda" if torch.cuda.is_available() else "cpu"

lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    target_modules=['q_proj', 'v_proj'],
    lora_dropout=0.05,
    bias='none',
    task_type="CAUSAL_LM"
)

model = AutoModelForCausalLM.from_pretrained(base_model)
model = get_peft_model(model, lora_config)
state_dict = load_file(lora_checkpoint)
model.load_state_dict(state_dict)
model = model.to(device)

tokenizer = AutoTokenizer.from_pretrained(base_model)
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# ###### Uploading dataset for test and function for generate answer by model

# %%
from datasets import load_dataset

dataset = load_dataset("ai-forever/POLLUX", split="test[:200]")

def generate_responses(batch, max_new_tokens=64):
    text = [f"<s>[INST] {example}[/INST]</s>" for example in batch['instruction']]

    tokens = tokenizer(
      text,
      truncation=True,
      padding=True,
      return_tensors="pt"
    ).to(model.device)
    
    with torch.no_grad():
      outputs = model.generate(**tokens, max_new_tokens=max_new_tokens, do_sample=False)

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return {"predicted": decoded}

# %% [markdown]
# ###### Get rouge, bleu scores and predictions

# %%
preds = dataset.map(generate_responses, batched=True, batch_size=8)

references = [a for a in preds['answer']]
predictions = [a for a in preds['predicted']]
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:   4%|▍         | 8/200 [00:04<01:49,  1.76 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:   8%|▊         | 16/200 [00:11<02:19,  1.32 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  12%|█▏        | 24/200 [00:14<01:36,  1.83 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  16%|█▌        | 32/200 [00:20<01:49,  1.53 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  20%|██        | 40/200 [00:22<01:23,  1.91 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  24%|██▍       | 48/200 [00:35<02:11,  1.15 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  28%|██▊       | 56/200 [00:42<02:07,  1.13 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  32%|███▏      | 64/200 [00:53<02:23,  1.05s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  36%|███▌      | 72/200 [01:00<02:07,  1.00 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  40%|████      | 80/200 [01:06<01:50,  1.09 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  44%|████▍     | 88/200 [01:20<02:09,  1.16s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  48%|████▊     | 96/200 [01:25<01:42,  1.02 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  52%|█████▏    | 104/200 [01:29<01:20,  1.19 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  56%|█████▌    | 112/200 [01:34<01:08,  1.29 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  60%|██████    | 120/200 [02:24<03:15,  2.45s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  64%|██████▍   | 128/200 [02:30<02:19,  1.94s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  68%|██████▊   | 136/200 [02:33<01:32,  1.44s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  72%|███████▏  | 144/200 [02:36<01:02,  1.12s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  76%|███████▌  | 152/200 [02:45<00:53,  1.12s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  80%|████████  | 160/200 [02:52<00:43,  1.08s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  84%|████████▍ | 168/200 [02:57<00:29,  1.10 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  88%|████████▊ | 176/200 [03:17<00:33,  1.41s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  92%|█████████▏| 184/200 [03:22<00:18,  1.17s/ examples]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map:  96%|█████████▌| 192/200 [03:24<00:07,  1.12 examples/s]Setting `pad_token_id` to `eos_token_id`:4 for open-end generation.
# Map: 100%|██████████| 200/200 [03:32<00:00,  1.06s/ examples]

# %% [markdown]
# ###### Get some references and generated answers

# %%
import evaluate

rouge = evaluate.load("rouge")
bleu = evaluate.load("bleu")

rouge_score = rouge.compute(predictions=predictions, references=references)
bleu_score = bleu.compute(predictions=predictions, references=references)

print("Rouge Score:", rouge_score)
print("Bleu Score:", bleu_score)
# Out:
# Rouge Score: {'rouge1': np.float64(0.12417919367405877), 'rouge2': np.float64(0.056647612097115566), 'rougeL': np.float64(0.11901776602841369), 'rougeLsum': np.float64(0.12329286965614666)}
# Bleu Score: {'bleu': 0.0531382455687766, 'precisions': [0.20163888348360035, 0.07326659573082017, 0.04462279993893263, 0.032135112045738316], 'brevity_penalty': 0.7832546435533129, 'length_ratio': 0.8036663770634231, 'translation_length': 46251, 'reference_length': 57550}

# %%
import random
for i in random.sample(range(len(predictions)), 5):
    print(f"Instruction: {dataset[i]['instruction']}")
    print(f"True answer: {dataset[i]['answer']}")
    print(f"Generated answer: {predictions[i]}")
    print("_" * 50)
# Out:
# Instruction: Составь мне план научного доклада об измерении содержания метана в испарениях над морем Лаптевых.
# True answer: Ниже приведён примерный план научного доклада на тему «Измерение содержания метана в испарениях над морем Лаптевых». Каждый раздел может быть дополнен более детальной информацией или статистическими данными в зависимости от объёма работы и целей исследования.
#
# 1. Введение
#    1.1. Актуальность исследования
#        – Краткое описание глобальных климатических изменений и роли метана как парникового газа.
#        – Обоснование важности изучения выбросов метана в арктических регионах.
#    1.2. Цели и задачи
#        – Общая цель: получить данные о концентрациях метана в испарениях над морем Лаптевых и выявить источники выбросов.
#        – Конкретные задачи (например, усовершенствование методологии измерения, определение влияющих факторов и т.п.).
#
# 2. Обзор литературы и теоретические предпосылки
#    2.1. Метан как парниковый газ
#        – Основные характеристики метана, его роль в парниковом эффекте.
#        – Краткие сведения о процессах образования и высвобождения метана.
#    2.2. Особенности арктических морей
#        – Гидрологические и климатические условия моря Лаптевых.
#        – Периоды ледообразования и его влияние на процессы газообмена.
#    2.3. Источники метана в Арктике
#        – Биологические: микробиологические процессы в донных отложениях, растительность приморских зон.
#        – Геологические: гидраты метана, подводные выходы газа.
#    2.4. Ранее проведённые исследования
#        – Краткий обзор уже имеющихся результатов измерений содержания метана в северных морях.
#        – Существующие модели потоков метана и их ограничения.
#
# 3. Методология исследования
#    3.1. Площадь исследования и план экспедиции
#        – Описание района исследований (координаты, особенности рельефа дна, климатические условия).
#        – Сезонность: выбор времени года для проведения измерений.
#    3.2. Методика отбора проб
#        – Использование судно-лаборатории или автоматизированных буёв.
#        – Подробное описание способов отбора проб воздуха: объём, частота, глубина забора (если используется анализ близ Поверхности моря).
#    3.3. Приборы и оборудование
#        – Хроматографы, газоанализаторы (NDIR-датчики, лазерные спектрометры), особенности их настройки и работы.
#        – Стандартные образцы и калибровка оборудования.
#    3.4. Лабораторная обработка и анализ
#        – Методы хранения и транспортировки проб (если была взята проба на борт).
#        – Алгоритмы обработки данных, расчёт концентраций и потоков метана.
#    3.5. Средства дистанционного зондирования (при необходимости)
#        – Использование спутниковых данных (например, TROPOMI) для валидации результатов наземных измерений.
#
# 4. Результаты
#    4.1. Пространственно-временное распределение концентраций метана
#        – Карты распределения метана в разные периоды экспедиции или в разные сезоны.
#        – Графики изменения концентрации метана по времени и в связи с условиями окружающей среды (температура, ледовая обстановка, атмосферное давление).
#    4.2. Оценка потоков метана
#        – Расчёт скоростей испарения (или выделения) метана.
#        – Сравнение полученных величин с известными научными данными по другим арктическим регионам.
#    4.3. Связь концентраций метана с внешними факторами
#        – Метеорологические показатели, ледовая обстановка, солёность воды.
#        – Возможная связь с процессами деградации подводной вечной мерзлоты или выходами подводных газогидратов.
#
# 5. Обсуждение
#    5.1. Интерпретация полученных результатов
#        – Влияние климатической изменчивости и сезонного таяния льдов на параметры выбросов метана.
#        – Возможные механизмы образования локальных «горячих точек» метана.
#    5.2. Сравнительный анализ с другими регионами Арктики
#        – Сопоставление с исследованиями над морем Восточно-Сибирским, Баренцевым морем и т.д.
#        – Оценка стандартных моделей и реальных измерений.
#    5.3. Точность и ограничения метода
#        – Особенности методологий, возможные источники погрешности.
#        – Необходимость дополнительных исследований или калибровочных методов.
#
# 6. Выводы и перспективы дальнейших исследований
#    6.1. Ключевые выводы
#        – Основные итоги по концентрациям и потокам метана, выявленные источники и факторы влияния.
#        – Вклад данного исследования в понимание роли моря Лаптевых в арктическом метановом балансе.
#    6.2. Рекомендации по дальнейшим исследованиям
#        – Развитие методов дистанционного мониторинга.
#        – Проведение постоянных (круглогодичных) измерений для оценки динамики выбросов.
#    6.3. Практическое применение
#        – Использование данных для глобальных климатических моделей.
#        – Поддержка экологических и природоохранных решений.
#
# 7. Список литературы
#    – Список использованных источников, статей и научных публикаций.
#    – Документы и базы данных (спутниковые данные, отчёты научных экспедиций, карты региона и т.д.).
#
# Данный план охватывает основные аспекты, которые следует отразить в научном докладе об измерении содержания метана в испарениях над морем Лаптевых. Он может быть адаптирован или расширен в зависимости от конкретных целей исследования и аудитории доклада.
# Generated answer: [INST] Составь мне план научного доклада об измерении содержания метана в испарениях над морем Лаптевых.[/INST] РИМОВО - Мельница «Наука» на месте снесенного храмового комплекса Опарины
# Смотрите также: «Механизм разрушения» по теме РИМОВО, а также подробное описание и фото уничтожения исторического объекта в ходе
# __________________________________________________
# Instruction: Составь план действий, если я оказался в старой страшной церкви ночью, а вокруг меня летает гроб с очень страшной паночкой. Она ещё приговаривает: «Ко мне, упыри, ко мне, вурдалаки». Из оружия у меня есть только Псалтырь и мел. Ещё входные двери заперты снаружи.
# True answer: В такой экстремальной и фантастической ситуации важно сохранять спокойствие и использовать имеющиеся ресурсы для защиты и побега. Вот план действий:
#
# 1. **Оценка ситуации**:
#    - Сначала проверь, нет ли других выходов: окон, чердака или подвала, через которые можно выйти.
#    - Обрати внимание на расположение гроба и паночки: избегай резких движений, чтобы не привлекать к себе внимание.
#
# 2. **Создание защитного круга**:
#    - Используй мел, чтобы нарисовать круг вокруг себя. В фольклоре круг считается защитой от злых духов.
#    - Убедись, что круг замкнут и не имеет разрывов.
#
# 3. **Использование Псалтыри**:
#    - Начни читать или читай вслух молитвы из Псалтыри. В христианской традиции молитвы считаются сильным средством против злых сил.
#    - Попробуй использовать «Отче наш» или «Символ веры», если не знаешь специфических антидемонических молитв.
#
# 4. **Отвлечение и поиск помощи**:
#    - Если паночка приближается, попробуй отвлечь её, бросив в сторону какой-либо предмет, например, подушку или стул.
#    - Обрати внимание на окна или двери, через которые можно подать сигнал или позвать на помощь (например, стуком).
#
# 5. **Поиск альтернативных выходов**:
#    - Если круг и молитвы не помогают, попробуй найти слабые места в запорах дверей или окнах. Возможно, есть инструменты в церкви, которые можно использовать для открывания двери изнутри.
#    - Проверь, нет ли подвала или чердака с выходом наружу.
#
# 6. **Психологическая устойчивость**:
#    - Постарайся сохранять спокойствие и не поддаваться панике. Глубоко дыши и сосредоточься на плане действий.
#    - Если нет другого выхода, попробуй вступить в диалог с паночкой, чтобы выяснить, можно ли как-то договориться или убедить её отпустить тебя.
#
# 7. **После выхода из церкви**:
#    - Немедленно позвони в полицию или другим службам помощи и сообщи о происшествии.
#    - Если возможно, оставайся на безопасном расстоянии от церкви до прибытия помощи.
#
# Помни, что в реальной жизни такие ситуации маловероятны, и если ты находишься в опасной или стрессовой ситуации, важно обратиться за реальной помощью.
# Generated answer: [INST] Составь план действий, если я оказался в старой страшной церкви ночью, а вокруг меня летает гроб с очень страшной паночкой. Она ещё приговаривает: «Ко мне, упыри, ко мне, вурдалаки». Из оружия у меня есть только Псалтырь и мел. Ещё входные двери заперты снаружи.[/INST]  Экскурсия в заповедник
# Главная → Экскурсии → Экология → Экскурсия в заповедник
